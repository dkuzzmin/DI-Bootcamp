# %% [markdown]
# <a href="https://colab.research.google.com/github/dkuzzmin/DI-Bootcamp/blob/main/Week4/Day4/Day4_XC_XP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exercises from day learning**

# %%
import pandas as pd

# %%
df = pd.read_csv('electronics.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1c975bedc3de> in <cell line: 1>()
# ----> 1 df = pd.read_csv('electronics.csv')
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'electronics.csv'

# %% [markdown]
# Remove years from warranty column - make it an integer, to allow us to graph/measure the data in that column.
#
# Fill in missing prices based on similar/identical products (Product and Price)
#
# Maybe find missing ages based on Name of customer. If not, fill with median age.
#
# (Potentially drop rows with missing names. Based on the specific)
#
# Fill in missing waranties with 0.

# %%
# for i in range(len(df)):
#     # print(df.iloc[i]['Warranty'])
#    if type(df.iloc[i]['Warranty']) == str:
#       df.iloc[i]['Warranty'] = df.iloc[i]['Warranty'].replace(' years','')
#    if type(df.iloc[i]['Warranty']) == str:
#       df.iloc[i]['Warranty'] = df.iloc[i]['Warranty'].replace(' year','')

df["Warranty"] = df["Warranty"].str.replace(' years','')
df["Warranty"] = df["Warranty"].str.replace(' year','')
df
# Out:
#     Unnamed: 0            Name   Age Product Purchased  Price        Date  \
# 0            0    James Wilson  21.0          E-reader    250  2022-02-10
# 1            1   Margaret King  59.0            Camera    700  2022-03-22
# 2            2    David Walker  53.0            Laptop    800  2022-09-06
# 3            3    James Wilson  65.0            Camera    700  2022-02-22
# 4            4     Joseph Hall  63.0        Headphones    100  2022-12-14
# 5            5     Emily Davis  50.0            Camera    700  2022-03-30
# 6            6       Susan Lee  36.0               NaN    250  2022-02-05
# 7            7  Jennifer Clark  42.0               NaN    250  2022-08-25
# 8            8   Michael Brown  40.0          Speakers    150  2022-04-15
# 9            9   Barbara Jones  25.0        Headphones    100  2022-11-14
# 10          10   Sarah Johnson   NaN            Laptop    800  2022-03-15
# 11          11     Maria Lewis  30.0          Speakers    150  2022-08-26
# 12          12     Maria Lewis  48.0        Smartphone    600  2022-11-17
# 13          13   Robert Harris  41.0        Smartwatch    250  2022-09-02
# 14          14   Barbara Jones  45.0          Speakers    150  2022-04-02
# 15          15   Olivia Martin  49.0        Smartphone    600  2022-01-27
# 16          16        John Doe  40.0          E-reader    250  2022-09-06
# 17          17       Susan Lee  25.0        Smartphone    600  2022-02-13
# 18          18     Maria Lewis  44.0            Tablet    400         NaN
# 19          19       Susan Lee  44.0            Camera    700  2022-04-08
#
#    Warranty
# 0         3
# 1       NaN
# 2         2
# 3         2
# 4       NaN
# 5         2
# 6         3
# 7       NaN
# 8       NaN
# 9       NaN
# 10        3
# 11        3
# 12        2
# 13      NaN
# 14        2
# 15        2
# 16        1
# 17        2
# 18      NaN
# 19        3

# %%
df['Warranty'][df['Warranty'].isna()] = 0
df["Warranty"] = df["Warranty"].astype(int)
df
# Out:
# <ipython-input-72-71fa6c038850>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Warranty'][df['Warranty'].isna()] = 0
#     Unnamed: 0            Name   Age Product Purchased  Price        Date  \
# 0            0    James Wilson  21.0          E-reader    250  2022-02-10
# 1            1   Margaret King  59.0            Camera    700  2022-03-22
# 2            2    David Walker  53.0            Laptop    800  2022-09-06
# 3            3    James Wilson  65.0            Camera    700  2022-02-22
# 4            4     Joseph Hall  63.0        Headphones    100  2022-12-14
# 5            5     Emily Davis  50.0            Camera    700  2022-03-30
# 6            6       Susan Lee  36.0               NaN    250  2022-02-05
# 7            7  Jennifer Clark  42.0               NaN    250  2022-08-25
# 8            8   Michael Brown  40.0          Speakers    150  2022-04-15
# 9            9   Barbara Jones  25.0        Headphones    100  2022-11-14
# 10          10   Sarah Johnson   NaN            Laptop    800  2022-03-15
# 11          11     Maria Lewis  30.0          Speakers    150  2022-08-26
# 12          12     Maria Lewis  48.0        Smartphone    600  2022-11-17
# 13          13   Robert Harris  41.0        Smartwatch    250  2022-09-02
# 14          14   Barbara Jones  45.0          Speakers    150  2022-04-02
# 15          15   Olivia Martin  49.0        Smartphone    600  2022-01-27
# 16          16        John Doe  40.0          E-reader    250  2022-09-06
# 17          17       Susan Lee  25.0        Smartphone    600  2022-02-13
# 18          18     Maria Lewis  44.0            Tablet    400         NaN
# 19          19       Susan Lee  44.0            Camera    700  2022-04-08
#
#     Warranty
# 0          3
# 1          0
# 2          2
# 3          2
# 4          0
# 5          2
# 6          3
# 7          0
# 8          0
# 9          0
# 10         3
# 11         3
# 12         2
# 13         0
# 14         2
# 15         2
# 16         1
# 17         2
# 18         0
# 19         3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         20 non-null     int64
#  1   Name               20 non-null     object
#  2   Age                19 non-null     float64
#  3   Product Purchased  18 non-null     object
#  4   Price              20 non-null     int64
#  5   Date               19 non-null     object
#  6   Warranty           20 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1.2+ KB

# %%
import numpy as np
df.Price[df['Name'] == 'John Doe'] = np.nan
# Out:
# <ipython-input-109-ba34e88dd53a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Price[df['Name'] == 'John Doe'] = np.nan

# %%
df
# Out:
#     Unnamed: 0            Name   Age Product Purchased  Price        Date  \
# 0            0    James Wilson  21.0          E-reader  250.0  2022-02-10
# 1            1   Margaret King  59.0            Camera  700.0  2022-03-22
# 2            2    David Walker  53.0            Laptop  800.0  2022-09-06
# 3            3    James Wilson  65.0            Camera  700.0  2022-02-22
# 4            4     Joseph Hall  63.0        Headphones  100.0  2022-12-14
# 5            5     Emily Davis  50.0            Camera  700.0  2022-03-30
# 6            6       Susan Lee  36.0               NaN  250.0  2022-02-05
# 7            7  Jennifer Clark  42.0               NaN  250.0  2022-08-25
# 8            8   Michael Brown  40.0          Speakers  150.0  2022-04-15
# 9            9   Barbara Jones  25.0        Headphones  100.0  2022-11-14
# 10          10   Sarah Johnson   NaN            Laptop  800.0  2022-03-15
# 11          11     Maria Lewis  30.0          Speakers  150.0  2022-08-26
# 12          12     Maria Lewis  48.0        Smartphone  600.0  2022-11-17
# 13          13   Robert Harris  41.0        Smartwatch  250.0  2022-09-02
# 14          14   Barbara Jones  45.0          Speakers  150.0  2022-04-02
# 15          15   Olivia Martin  49.0        Smartphone  600.0  2022-01-27
# 16          16        John Doe  40.0          E-reader    NaN  2022-09-06
# 17          17       Susan Lee  25.0        Smartphone  600.0  2022-02-13
# 18          18     Maria Lewis  44.0            Tablet  400.0         NaN
# 19          19       Susan Lee  44.0            Camera  700.0  2022-04-08
#
#     Warranty
# 0          3
# 1          0
# 2          2
# 3          2
# 4          0
# 5          2
# 6          3
# 7          0
# 8          0
# 9          0
# 10         3
# 11         3
# 12         2
# 13         0
# 14         2
# 15         2
# 16         1
# 17         2
# 18         0
# 19         3

# %%
df[df['Product Purchased'] == 'E-reader']
# Out:
#     Unnamed: 0          Name   Age Product Purchased  Price        Date  \
# 0            0  James Wilson  21.0          E-reader  250.0  2022-02-10
# 16          16      John Doe  40.0          E-reader    NaN  2022-09-06
#
#     Warranty Product Purchaesd
# 0          3          E-reader
# 16         1          E-reader

# %%
df.drop('Product Purchaesd', axis=1, inplace=True)

# %%
df[df['Product Purchased'] == 'E-reader']
# Out:
#     Unnamed: 0          Name   Age Product Purchased  Price        Date  \
# 0            0  James Wilson  21.0          E-reader  250.0  2022-02-10
# 16          16      John Doe  40.0          E-reader    NaN  2022-09-06
#
#     Warranty
# 0          3
# 16         1

# %%
df['Price'].loc[16] = 250
# Out:
# <ipython-input-111-1d9e12b09990>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'].loc[16] = 250

# %%
df
# Out:
#     Unnamed: 0            Name   Age Product Purchased  Price        Date  \
# 0            0    James Wilson  21.0          E-reader  250.0  2022-02-10
# 1            1   Margaret King  59.0            Camera  700.0  2022-03-22
# 2            2    David Walker  53.0            Laptop  800.0  2022-09-06
# 3            3    James Wilson  65.0            Camera  700.0  2022-02-22
# 4            4     Joseph Hall  63.0        Headphones  100.0  2022-12-14
# 5            5     Emily Davis  50.0            Camera  700.0  2022-03-30
# 6            6       Susan Lee  36.0               NaN  250.0  2022-02-05
# 7            7  Jennifer Clark  42.0               NaN  250.0  2022-08-25
# 8            8   Michael Brown  40.0          Speakers  150.0  2022-04-15
# 9            9   Barbara Jones  25.0        Headphones  100.0  2022-11-14
# 10          10   Sarah Johnson   NaN            Laptop  800.0  2022-03-15
# 11          11     Maria Lewis  30.0          Speakers  150.0  2022-08-26
# 12          12     Maria Lewis  48.0        Smartphone  600.0  2022-11-17
# 13          13   Robert Harris  41.0        Smartwatch  250.0  2022-09-02
# 14          14   Barbara Jones  45.0          Speakers  150.0  2022-04-02
# 15          15   Olivia Martin  49.0        Smartphone  600.0  2022-01-27
# 16          16        John Doe  40.0          E-reader  250.0  2022-09-06
# 17          17       Susan Lee  25.0        Smartphone  600.0  2022-02-13
# 18          18     Maria Lewis  44.0            Tablet  400.0         NaN
# 19          19       Susan Lee  44.0            Camera  700.0  2022-04-08
#
#     Warranty
# 0          3
# 1          0
# 2          2
# 3          2
# 4          0
# 5          2
# 6          3
# 7          0
# 8          0
# 9          0
# 10         3
# 11         3
# 12         2
# 13         0
# 14         2
# 15         2
# 16         1
# 17         2
# 18         0
# 19         3

# %%
df[df['Name'] == 'Sarah Johnson']
# Out:
#     Unnamed: 0           Name  Age Product Purchased  Price        Date  \
# 10          10  Sarah Johnson  NaN            Laptop  800.0  2022-03-15
#
#     Warranty
# 10         3

# %% [markdown]
# We dont have another purchaces of this customer, so we will assign an average age

# %%
df['Age'].loc[10] = df['Age'].mean().astype(int)
# Out:
# <ipython-input-122-f3fc7f5e61f5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].loc[10] = df['Age'].mean().astype(int)

# %%
df
# Out:
#     Unnamed: 0            Name   Age Product Purchased  Price        Date  \
# 0            0    James Wilson  21.0          E-reader  250.0  2022-02-10
# 1            1   Margaret King  59.0            Camera  700.0  2022-03-22
# 2            2    David Walker  53.0            Laptop  800.0  2022-09-06
# 3            3    James Wilson  65.0            Camera  700.0  2022-02-22
# 4            4     Joseph Hall  63.0        Headphones  100.0  2022-12-14
# 5            5     Emily Davis  50.0            Camera  700.0  2022-03-30
# 6            6       Susan Lee  36.0               NaN  250.0  2022-02-05
# 7            7  Jennifer Clark  42.0               NaN  250.0  2022-08-25
# 8            8   Michael Brown  40.0          Speakers  150.0  2022-04-15
# 9            9   Barbara Jones  25.0        Headphones  100.0  2022-11-14
# 10          10   Sarah Johnson  43.0            Laptop  800.0  2022-03-15
# 11          11     Maria Lewis  30.0          Speakers  150.0  2022-08-26
# 12          12     Maria Lewis  48.0        Smartphone  600.0  2022-11-17
# 13          13   Robert Harris  41.0        Smartwatch  250.0  2022-09-02
# 14          14   Barbara Jones  45.0          Speakers  150.0  2022-04-02
# 15          15   Olivia Martin  49.0        Smartphone  600.0  2022-01-27
# 16          16        John Doe  40.0          E-reader  250.0  2022-09-06
# 17          17       Susan Lee  25.0        Smartphone  600.0  2022-02-13
# 18          18     Maria Lewis  44.0            Tablet  400.0         NaN
# 19          19       Susan Lee  44.0            Camera  700.0  2022-04-08
#
#     Warranty
# 0          3
# 1          0
# 2          2
# 3          2
# 4          0
# 5          2
# 6          3
# 7          0
# 8          0
# 9          0
# 10         3
# 11         3
# 12         2
# 13         0
# 14         2
# 15         2
# 16         1
# 17         2
# 18         0
# 19         3

# %% [markdown]
# **🌟 Exercise 1: Duplicate Detection And Removal**

# %%
import pandas as pd

# %%
df = pd.read_csv('tested.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
We dont have duplicated data

# %% [markdown]
# ** Exercise 2: Handling Missing Values**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# We have missed vaules in "Age", "Fare", "Cabin"

# %%
df[df['Age'].isna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 10           902         0       3
# 22           914         1       1
# 29           921         0       3
# 33           925         1       3
# 36           928         1       3
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 10                                    Ilieff, Mr. Ylio    male  NaN      0
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 29                                   Samaan, Mr. Elias    male  NaN      2
# 33   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female  NaN      1
# 36                                 Roth, Miss. Sarah A  female  NaN      0
# ..                                                 ...     ...  ...    ...
# 408                    Riordan, Miss. Johanna Hannah""  female  NaN      0
# 410                             Naughton, Miss. Hannah  female  NaN      0
# 413                                 Spector, Mr. Woolf    male  NaN      0
# 416                                Ware, Mr. Frederick    male  NaN      0
# 417                           Peter, Master. Michael J    male  NaN      1
#
#      Parch      Ticket     Fare Cabin Embarked
# 10       0      349220   7.8958   NaN        S
# 22       0    PC 17598  31.6833   NaN        S
# 29       0        2662  21.6792   NaN        C
# 33       2  W./C. 6607  23.4500   NaN        S
# 36       0      342712   8.0500   NaN        S
# ..     ...         ...      ...   ...      ...
# 408      0      334915   7.7208   NaN        Q
# 410      0      365237   7.7500   NaN        Q
# 413      0   A.5. 3236   8.0500   NaN        S
# 416      0      359309   8.0500   NaN        S
# 417      1        2668  22.3583   NaN        C
#
# [86 rows x 12 columns]

# %%
df['Age'].mean()
# Out:
# 30.272590361445783

# %%
 df['Age'] = df['Age'].fillna(30)

# %%
df.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5                          Svensson, Mr. Johan Cervin    male  14.0      0
# 6                                Connolly, Miss. Kate  female  30.0      0
# 7                        Caldwell, Mr. Albert Francis    male  26.0      1
# 8           Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 9                             Davies, Mr. John Samuel    male  21.0      2
# 10                                   Ilieff, Mr. Ylio    male  30.0      0
# 11                         Jones, Mr. Charles Cresson    male  46.0      0
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 13                               Howard, Mr. Benjamin    male  63.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
#
#     Parch       Ticket     Fare Cabin Embarked
# 0       0       330911   7.8292   NaN        Q
# 1       0       363272   7.0000   NaN        S
# 2       0       240276   9.6875   NaN        Q
# 3       0       315154   8.6625   NaN        S
# 4       1      3101298  12.2875   NaN        S
# 5       0         7538   9.2250   NaN        S
# 6       0       330972   7.6292   NaN        Q
# 7       1       248738  29.0000   NaN        S
# 8       0         2657   7.2292   NaN        C
# 9       0    A/4 48871  24.1500   NaN        S
# 10      0       349220   7.8958   NaN        S
# 11      0          694  26.0000   NaN        S
# 12      0        21228  82.2667   B45        S
# 13      0        24065  26.0000   NaN        S
# 14      0  W.E.P. 5734  61.1750   E31        S

# %%
df[df['Cabin'].isna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 412         1304         1       3
# 413         1305         0       3
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 412                Henriksson, Miss. Jenny Lovisa  female  28.0      0      0
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket     Fare Cabin Embarked
# 0                330911   7.8292   NaN        Q
# 1                363272   7.0000   NaN        S
# 2                240276   9.6875   NaN        Q
# 3                315154   8.6625   NaN        S
# 4               3101298  12.2875   NaN        S
# ..                  ...      ...   ...      ...
# 412              347086   7.7750   NaN        S
# 413           A.5. 3236   8.0500   NaN        S
# 415  SOTON/O.Q. 3101262   7.2500   NaN        S
# 416              359309   8.0500   NaN        S
# 417                2668  22.3583   NaN        C
#
# [327 rows x 12 columns]

# %%
 df['Cabin'] = df['Cabin'].fillna('NoCabin')

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5                          Svensson, Mr. Johan Cervin    male  14.0      0
# 6                                Connolly, Miss. Kate  female  30.0      0
# 7                        Caldwell, Mr. Albert Francis    male  26.0      1
# 8           Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 9                             Davies, Mr. John Samuel    male  21.0      2
# 10                                   Ilieff, Mr. Ylio    male   NaN      0
# 11                         Jones, Mr. Charles Cresson    male  46.0      0
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 13                               Howard, Mr. Benjamin    male  63.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 15      del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1
# 16                                  Keane, Mr. Daniel    male  35.0      0
# 17                                  Assaf, Mr. Gerios    male  21.0      0
# 18                       Ilmakangas, Miss. Ida Livija  female  27.0      1
# 19              Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0      0
#
#     Parch            Ticket     Fare    Cabin Embarked
# 0       0            330911   7.8292  NoCabin        Q
# 1       0            363272   7.0000  NoCabin        S
# 2       0            240276   9.6875  NoCabin        Q
# 3       0            315154   8.6625  NoCabin        S
# 4       1           3101298  12.2875  NoCabin        S
# 5       0              7538   9.2250  NoCabin        S
# 6       0            330972   7.6292  NoCabin        Q
# 7       1            248738  29.0000  NoCabin        S
# 8       0              2657   7.2292  NoCabin        C
# 9       0         A/4 48871  24.1500  NoCabin        S
# 10      0            349220   7.8958  NoCabin        S
# 11      0               694  26.0000  NoCabin        S
# 12      0             21228  82.2667      B45        S
# 13      0             24065  26.0000  NoCabin        S
# 14      0       W.E.P. 5734  61.1750      E31        S
# 15      0     SC/PARIS 2167  27.7208  NoCabin        C
# 16      0            233734  12.3500  NoCabin        Q
# 17      0              2692   7.2250  NoCabin        C
# 18      0  STON/O2. 3101270   7.9250  NoCabin        S
# 19      0              2696   7.2250  NoCabin        C

# %%
df[df['Fare'].isna()]
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 152         1044         0       3  Storey, Mr. Thomas  male  60.5      0
#
#      Parch Ticket  Fare Cabin Embarked
# 152      0   3701   NaN   NaN        S

# %%
df[df['Ticket'] == 3701]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# We dont have another passengers from ticket 3701.
# We can replace missed fare with an average fare for 3 class

# %%
df[df['Pclass'] == 3]['Fare'].mean()
# Out:
# 12.459677880184334

# %%
df.loc[152,'Fare'] = 12.46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         418 non-null    float64
#  10  Cabin        418 non-null    object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# Exercise 3: Feature Engineering
#
# - Create new features, such as ‘Family Size’ from ‘SibSp’ and ‘Parch’, and ‘Title’ extracted from the ‘Name’ column.
# - Convert categorical variables into numerical form using techniques like one-hot encoding or label encoding.
# - Normalize or standardize numerical features if required.
#
# Hint: Utilize Pandas for data manipulation and scikit-learn’s preprocessing module for encoding.

# %%
df["Family Size"] = df['SibSp'] + df['Parch']

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# 6                          Connolly, Miss. Kate  female  30.0      0      0
# 7                  Caldwell, Mr. Albert Francis    male  26.0      1      1
# 8     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0      0
# 9                       Davies, Mr. John Samuel    male  21.0      2      0
#
#       Ticket     Fare    Cabin Embarked  Family Size
# 0     330911   7.8292  NoCabin        Q            0
# 1     363272   7.0000  NoCabin        S            1
# 2     240276   9.6875  NoCabin        Q            0
# 3     315154   8.6625  NoCabin        S            0
# 4    3101298  12.2875  NoCabin        S            2
# 5       7538   9.2250  NoCabin        S            0
# 6     330972   7.6292  NoCabin        Q            0
# 7     248738  29.0000  NoCabin        S            2
# 8       2657   7.2292  NoCabin        C            0
# 9  A/4 48871  24.1500  NoCabin        S            2

# %%
df["Title"] = df['Name'].str.extract('(Mrs.|Mr.|Miss.|Master.|Col.|Ms.|Rev.|Dr.|Dona.)')

# %%
df.head(15)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          Mr.         0       3
# 1          893         1       3
# 2          Mr.         0       2
# 3          Mr.         0       3
# 4          896         1       3
# 5          Mr.         0       3
# 6          NaN         1       3
# 7          Mr.         0       2
# 8          900         1       3
# 9          Mr.         0       3
# 10         Mr.         0       3
# 11         Mr.         0       1
# 12         904         1       1
# 13         Mr.         0       2
# 14         906         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5                          Svensson, Mr. Johan Cervin    male  14.0      0
# 6                                Connolly, Miss. Kate  female  30.0      0
# 7                        Caldwell, Mr. Albert Francis    male  26.0      1
# 8           Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 9                             Davies, Mr. John Samuel    male  21.0      2
# 10                                   Ilieff, Mr. Ylio    male  30.0      0
# 11                         Jones, Mr. Charles Cresson    male  46.0      0
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 13                               Howard, Mr. Benjamin    male  63.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
#
#     Parch       Ticket     Fare    Cabin Embarked  Family Size  Title
# 0       0       330911   7.8292  NoCabin        Q            0    Mr.
# 1       0       363272   7.0000  NoCabin        S            1   Mrs.
# 2       0       240276   9.6875  NoCabin        Q            0    Mr.
# 3       0       315154   8.6625  NoCabin        S            0    Mr.
# 4       1      3101298  12.2875  NoCabin        S            2   Mrs.
# 5       0         7538   9.2250  NoCabin        S            0    Mr.
# 6       0       330972   7.6292  NoCabin        Q            0  Miss.
# 7       1       248738  29.0000  NoCabin        S            2    Mr.
# 8       0         2657   7.2292  NoCabin        C            0   Mrs.
# 9       0    A/4 48871  24.1500  NoCabin        S            2    Mr.
# 10      0       349220   7.8958  NoCabin        S            0    Mr.
# 11      0          694  26.0000  NoCabin        S            0    Mr.
# 12      0        21228  82.2667      B45        S            1   Mrs.
# 13      0        24065  26.0000  NoCabin        S            1    Mr.
# 14      0  W.E.P. 5734  61.1750      E31        S            1   Mrs.

# %%
df[df['Title'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Family Size, Title]
# Index: []

# %% [markdown]
# Changing "Embarked" from string to numeric

# %%
df['Embarked'].unique()
# Out:
# array(['Q', 'S', 'C'], dtype=object)

# %%
newdf = df.replace('Q', 1)
newdf = newdf.replace('S', 2)
newdf = newdf.replace('C', 3)
newdf.sample(10)
# Out:
#     PassengerId  Survived  Pclass                                   Name  \
# 208         NaN         1       1          Rosenbaum, Miss. Edith Louise
# 234         Mr.         0       1              Cumings, Mr. John Bradley
# 216         NaN         1       3             Mahon, Miss. Bridget Delia
# 266         Mr.         0       1  Chisholm, Mr. Roderick Robert Crispin
# 163         Mr.         0       3                     Pearce, Mr. Ernest
# 278         Mr.         0       2                   Ware, Mr. John James
# 161         NaN         0       3         Touma, Master. Georges Youssef
# 135         Mr.         0       3              Carlsson, Mr. Carl Robert
# 390         Mr.         0       1             Payne, Mr. Vivian Ponsonby
# 2           Mr.         0       2              Myles, Mr. Thomas Francis
#
#         Sex   Age  SibSp  Parch    Ticket     Fare    Cabin  Embarked  \
# 208  female  33.0      0      0  PC 17613  27.7208      A11         3
# 234    male  39.0      1      0  PC 17599  71.2833      C85         3
# 216  female  30.0      0      0    330924   7.8792  NoCabin         1
# 266    male  30.0      0      0    112051   0.0000  NoCabin         2
# 163    male  30.0      0      0    343271   7.0000  NoCabin         2
# 278    male  30.0      1      0  CA 31352  21.0000  NoCabin         2
# 161    male   7.0      1      1      2650  15.2458  NoCabin         3
# 135    male  24.0      0      0    350409   7.8542  NoCabin         2
# 390    male  23.0      0      0     12749  93.5000      B24         2
# 2      male  62.0      0      0    240276   9.6875  NoCabin         1
#
#      Family Size    Title
# 208            0    Miss.
# 234            1      Mr.
# 216            0    Miss.
# 266            0      Mr.
# 163            0      Mr.
# 278            1      Mr.
# 161            2  Master.
# 135            0      Mr.
# 390            0      Mr.
# 2              0      Mr.

# %% [markdown]
# Changing 'Survived' colomn for boolean type

# %%
newdf1 = newdf.replace({0: False, 1: True})

# %%
newdf1.sample(10)
# Out:
#     PassengerId  Survived Pclass  \
# 278         Mr.     False      2
# 379         NaN     False      3
# 297         Mr.     False      3
# 61          Mr.     False      2
# 197         NaN      True      3
# 126         Mr.     False      3
# 48          940      True   True
# 153        1045      True      3
# 167         Mr.     False      3
# 237         Mr.     False      3
#
#                                                 Name     Sex   Age  SibSp  \
# 278                             Ware, Mr. John James    male  30.0   True
# 379                      Asplund, Master. Carl Edgar    male   5.0      4
# 297                                Samaan, Mr. Hanna    male  30.0      2
# 61                         McCrae, Mr. Arthur Gordon    male  32.0  False
# 197                      Nilsson, Miss. Berta Olivia  female  18.0  False
# 126                         Brobeck, Mr. Karl Rudolf    male  22.0  False
# 48   Bucknell, Mrs. William Robert (Emma Eliza Ward)  female  60.0  False
# 153   Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)  female  36.0  False
# 167                          Ford, Mr. Edward Watson    male  18.0      2
# 237                              Baccos, Mr. Raffull    male  20.0  False
#
#      Parch      Ticket     Fare    Cabin Embarked Family Size    Title
# 278  False    CA 31352     21.0  NoCabin        2        True      Mr.
# 379      2      347077  31.3875  NoCabin        2           6  Master.
# 297  False        2662  21.6792  NoCabin        3           2      Mr.
# 61   False      237216     13.5  NoCabin        2       False      Mr.
# 197  False      347066    7.775  NoCabin        2       False    Miss.
# 126  False      350045   7.7958  NoCabin        2       False      Mr.
# 48   False       11813  76.2917      D15        3       False     Mrs.
# 153      2      350405  12.1833  NoCabin        2           2     Mrs.
# 167      2  W./C. 6608   34.375  NoCabin        2           4      Mr.
# 237  False        2679    7.225  NoCabin        3       False      Mr.
