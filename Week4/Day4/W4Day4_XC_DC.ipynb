# %% [markdown]
# <a href="https://colab.research.google.com/github/dkuzzmin/DI-Bootcamp/blob/main/Week4/Day4/W4Day4_XC_DC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/datascience_salaries.csv")

# %%
df
# Out:
#       Unnamed: 0       job_title    job_type experience_level       location  \
# 0              0  Data scientist   Full Time           Senior  New York City
# 1              2  Data scientist   Full Time           Senior         Boston
# 2              3  Data scientist   Full Time           Senior         London
# 3              4  Data scientist   Full Time           Senior         Boston
# 4              5  Data scientist   Full Time           Senior  New York City
# ...          ...             ...         ...              ...            ...
# 1166        2243          ML Ops   Full Time           Senior        Toronto
# 1167        2249          ML Ops   Full Time           Senior         Boston
# 1168        2250          ML Ops   Full Time           Senior          Delhi
# 1169        2255          ML Ops   Full Time           Senior  San Francisco
# 1170        2259          ML Ops  Internship           Senior  New York City
#
#      salary_currency  salary
# ...

# %% [markdown]
# **Let's make a column with salaries in USD**

# %%
df['salary_currency'].unique()
# Out:
# array(['USD', 'EUR', 'GBP'], dtype=object)

# %%
df1 = df[df['salary_currency'] == 'GBP']['salary'] * 1.27
df2 = df[df['salary_currency'] == 'EUR']['salary'] * 1.10
df3 = df[df['salary_currency'] == 'USD']['salary']
df_usd = pd.concat([df1, df2, df3])
df['salary_in_usd'] = df_usd
df[newdf['salary_currency'] == 'EUR']
# Out:
#       Unnamed: 0         job_title   job_type experience_level  \
# 63            84    Data scientist  Full Time           Senior
# 94           123    Data scientist  Full Time              Mid
# 149          188    Data scientist  Full Time           Senior
# 182          226    Data scientist  Full Time              Mid
# 238          295    Data scientist  Full Time           Senior
# 354          444    Data scientist  Full Time           Senior
# 421          537      Data analyst  Full Time           Senior
# 762         1200          Big data  Full Time           Senior
# 1008        1800  Machine learning  Full Time           Senior
#
#             location salary_currency  salary  salary_in_usd
# 63            Madrid             EUR   36000        39600.0
# 94             Paris             EUR   50000        55000.0
# 149           Madrid             EUR   36000        39600.0
# 182           Berlin             EUR   58000        63800.0
# ...

# %% [markdown]
# **Normalize the ‘salary’ column using Min-Max normalization.**

# %%
df['salary_norm'] = (df['salary_in_usd'] - df['salary_in_usd'].min())/(df['salary_in_usd'].max() - df['salary_in_usd'].min())

# %%
df.sample(20)
# Out:
#       Unnamed: 0         job_title   job_type experience_level  \
# 473          627      Data analyst  Full Time              Mid
# 303          375    Data scientist  Full Time           Senior
# 894         1534  Machine learning  Full Time           Senior
# 217          266    Data scientist  Full Time           Senior
# 507          683      Data analyst  Full Time           Senior
# 278          348    Data scientist  Full Time              Mid
# 76            99    Data scientist  Full Time            Entry
# 517          708      Data analyst  Full Time              Mid
# 433          561      Data analyst  Full Time           Senior
# 679          959      Data analyst  Full Time              Mid
# 1052        1896  Machine learning  Full Time           Senior
# 57            78    Data scientist  Full Time           Senior
# 664          939      Data analyst  Full Time              Mid
# 164          206    Data scientist  Full Time           Senior
# ...

# %% [markdown]
# **Implement dimensionality reduction on the dataset.**

# %%
df_new = df.copy()
df_new['salary'] = df_new['salary']/1000
df_new['salary_in_usd'] = df_new['salary_in_usd']/1000
df_new
# Out:
#       Unnamed: 0       job_title    job_type experience_level       location  \
# 0              0  Data scientist   Full Time           Senior  New York City
# 1              2  Data scientist   Full Time           Senior         Boston
# 2              3  Data scientist   Full Time           Senior         London
# 3              4  Data scientist   Full Time           Senior         Boston
# 4              5  Data scientist   Full Time           Senior  New York City
# ...          ...             ...         ...              ...            ...
# 1166        2243          ML Ops   Full Time           Senior        Toronto
# 1167        2249          ML Ops   Full Time           Senior         Boston
# 1168        2250          ML Ops   Full Time           Senior          Delhi
# 1169        2255          ML Ops   Full Time           Senior  San Francisco
# 1170        2259          ML Ops  Internship           Senior  New York City
#
# ...

# %% [markdown]
# **Aggregate data by ‘experience_level’, calculating average and median salaries.**

# %%
agg_data = df_new.groupby('experience_level')['salary_in_usd'].agg(['mean', 'median'])

# %%
agg_data
# Out:
#                        mean  median
# experience_level
# Entry             36.111111    30.0
# Executive         76.076923    46.0
# Mid               51.786885    51.0
# Senior            75.088033    68.0
