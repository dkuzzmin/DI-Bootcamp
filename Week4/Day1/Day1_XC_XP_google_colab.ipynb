# %% [markdown]
# <a href="https://colab.research.google.com/github/dkuzzmin/DI-Bootcamp/blob/main/Week4/Day1/Day1_XC_XP_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
import pandas as pd

files.upload()
df = pd.read_csv('IRIS.csv')
# Out:
#      <input type="file" id="files-37f065f1-fc2f-4c2d-9a65-413e5c481797" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-37f065f1-fc2f-4c2d-9a65-413e5c481797">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %%
print(df["sepal_length"].mean().round(),
df["sepal_width"].mean().round(),
df["petal_length"].mean().round(),
df["petal_width"].mean().round())
# Out:
# 6.0 3.0 4.0 1.0

# %%
print(df["sepal_length"].median().round(),
df["sepal_width"].median().round(),
df["petal_length"].median().round(),
df["petal_width"].median().round())
# Out:
# 6.0 3.0 4.0 1.0

# %%
df["sepal_length"].mode().round()
# Out:
# 0    5.0
# Name: sepal_length, dtype: float64

# %%
df.mode()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0           5.0          3.0           1.5          0.2      Iris-setosa
# 1           NaN          NaN           NaN          NaN  Iris-versicolor
# 2           NaN          NaN           NaN          NaN   Iris-virginica

# %%
plt.bar([1,2,3,4],[df["sepal_length"].mean(),df["sepal_width"].mean(),df["petal_length"].mean(),df["petal_width"].mean()])
# Out:
# <BarContainer object of 4 artists>

# %%
Exercise 6: Basic Observation Skills In Data Analysis

# %%
from google.colab import files
import pandas as pd

files.upload()
df1 = pd.read_csv('Time Americans Spend Sleeping.csv')
# Out:
#      <input type="file" id="files-69b3eed7-2417-42b9-93f8-06f9ec6c48f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69b3eed7-2417-42b9-93f8-06f9ec6c48f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1.head(7)
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
# 5      5  2008  Annual                      8.60           0.023     All days
# 6      6  2009  Annual                      8.67           0.023     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both
# 5  15 years and over  Sleeping  Both
# 6  15 years and over  Sleeping  Both

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
#  1   Year                      945 non-null    int64
#  2   Period                    945 non-null    object
#  3   Avg hrs per day sleeping  945 non-null    float64
#  4   Standard Error            945 non-null    float64
#  5   Type of Days              945 non-null    object
#  6   Age Group                 945 non-null    object
#  7   Activity                  945 non-null    object
#  8   Sex                       945 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB

# %%
df1.isna().sum()
# Out:
# index                       0
# Year                        0
# Period                      0
# Avg hrs per day sleeping    0
# Standard Error              0
# Type of Days                0
# Age Group                   0
# Activity                    0
# Sex                         0
# dtype: int64

# %%
df1.nunique().sort_values(ascending=False)
# Out:
# index                       945
# Avg hrs per day sleeping    221
# Standard Error              158
# Year                         15
# Age Group                     7
# Type of Days                  3
# Sex                           3
# Period                        1
# Activity                      1
# dtype: int64

# %%
df1["Sex"].unique()
# Out:
# array(['Both', 'Men', 'Women'], dtype=object)

# %%
sum(df1["Sex"] == 'Men')
# Out:
# 315

# %%
sum(df1["Sex"] == 'Women')
# Out:
# 315

# %%
df1["Type of Days"].unique()
# Out:
# array(['All days', 'Nonholiday weekdays', 'Weekend days and holidays'],
#       dtype=object)

# %%
Not interested for analysis columns: index, Period, Activity - because it is the same for whole data
The remaining columns are important
