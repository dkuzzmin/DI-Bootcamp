# %% [markdown]
# <a href="https://colab.research.google.com/github/dkuzzmin/DI-Bootcamp/blob/main/Week4/Day3/Day3_XC_XP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercise 1 : Import A File From Kaggle
import pandas as pd

# %%
pip install opendatasets

# %%
import opendatasets as od

# %%
od.download(
    "https://www.kaggle.com/datasets/brendan45774/test-file")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: kuzzmindima
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 11.2k/11.2k [00:00<00:00, 16.0MB/s]

# %%
df = pd.read_csv("test-file/tested.csv")
df.head(1)
# Out:
#    PassengerId  Survived  Pclass              Name   Sex   Age  SibSp  Parch  \
# 0          892         0       3  Kelly, Mr. James  male  34.5      0      0
#
#    Ticket    Fare Cabin Embarked
# 0  330911  7.8292   NaN        Q

# %%
#Exercise 2: Importing A CSV File
df1 = pd.read_csv('IRIS.csv')
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Exercise 3: Reading JSON Data


# import json
json_data = pd.read_json('https://jsonplaceholder.typicode.com/posts')
# print(json_data.head())
df2 = json_data
df2.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %%
# 🌟 Exercise 4: Loading Data From An Excel File

excel_data = pd.read_excel('file_example_XLS_10.xls', index_col=0)
excel_data.head(3)
# Out:
#   First Name  Last Name  Gender        Country  Age        Date    Id
# 0
# 1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 3     Philip       Gent    Male         France   36  21/05/2015  2587

# %%
# Exercise 5 : Export A Dataframe To Excel Format And JSON Format.

data =  {'Name': ['Tesla Model S','Tesla Model X'], 'Price': [300000, 450000], 'Amount': [5, 12]}

df3 = pd.DataFrame(data)

df3
# Out:
#             Name   Price  Amount
# 0  Tesla Model S  300000       5
# 1  Tesla Model X  450000      12

# %%
df3.to_json('inventory.json')

# %%
df3.to_excel('inventory.xlsx', sheet_name='Sheet1')
