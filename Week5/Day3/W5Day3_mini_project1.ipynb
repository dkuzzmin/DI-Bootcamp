# %% [markdown]
# <a href="https://colab.research.google.com/github/dkuzzmin/DI-Bootcamp/blob/main/Week5/Day3/W5Day3_mini_project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/penguins.csv')

# %% [markdown]
# # Data Cleaning and Exploratory Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %% [markdown]
# clean%
# duplicat
# nan
# male female
# data type str to numbers

# %%
df[df['bill_depth_mm'].isna()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  year
# 3            NaN  NaN  2007
# 271          NaN  NaN  2009

# %%
df[df['sex'].isna()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  Gentoo     Biscoe            44.5           15.7              217.0
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  year
# 3            NaN  NaN  2007
# 8         3475.0  NaN  2007
# ...

# %%
df.dropna(subset=['bill_length_mm'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 342 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            342 non-null    object
#  1   island             342 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               342 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 24.0+ KB

# %%
df[df.duplicated(keep="last")]
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %%
df.duplicated(keep="last").sum()
# Out:
# 0

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df['year'].unique()
# Out:
# array([2007, 2008, 2009])

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   342.000000
# mean   2008.029240
# std       0.817168
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
df[df['species'] == 'Adelie'].describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      151.000000     151.000000         151.000000   151.000000
# mean        38.791391      18.346358         189.953642  3700.662252
# std          2.663405       1.216650           6.539457   458.566126
# min         32.100000      15.500000         172.000000  2850.000000
# 25%         36.750000      17.500000         186.000000  3350.000000
# 50%         38.800000      18.400000         190.000000  3700.000000
# 75%         40.750000      19.000000         195.000000  4000.000000
# max         46.000000      21.500000         210.000000  4775.000000
#
#               year
# count   151.000000
# mean   2008.019868
# std       0.820327
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
df[df['species'] == 'Gentoo'].describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      123.000000     123.000000         123.000000   123.000000
# mean        47.504878      14.982114         217.186992  5076.016260
# std          3.081857       0.981220           6.484976   504.116237
# min         40.900000      13.100000         203.000000  3950.000000
# 25%         45.300000      14.200000         212.000000  4700.000000
# 50%         47.300000      15.000000         216.000000  5000.000000
# 75%         49.550000      15.700000         221.000000  5500.000000
# max         59.600000      17.300000         231.000000  6300.000000
#
#               year
# count   123.000000
# mean   2008.073171
# std       0.791043
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
df[df['species'] == 'Chinstrap'].describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count       68.000000      68.000000          68.000000    68.000000
# mean        48.833824      18.420588         195.823529  3733.088235
# std          3.339256       1.135395           7.131894   384.335081
# min         40.900000      16.400000         178.000000  2700.000000
# 25%         46.350000      17.500000         191.000000  3487.500000
# 50%         49.550000      18.450000         196.000000  3700.000000
# 75%         51.075000      19.400000         201.000000  3950.000000
# max         58.000000      20.800000         212.000000  4800.000000
#
#               year
# count    68.000000
# mean   2007.970588
# std       0.863360
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# **Summury:**
# We has dataset with 3 types of penguins, living on 3 islands. Dataset covers data for 3 years of measurements.
#
# Penguins of type Gentoo have more mass and flipper lenght
#
# Chinstrap's penguins have more lenght of bill
#
# Adelie penguins have a smaller bill lenght and flipper lenght

# %% [markdown]
# # - Species Distribution: Use a bar chart to show the distribution of penguin species.

# %%
data = df['species'].value_counts(sort=False)
data.index
# Out:
# Index(['Adelie', 'Gentoo', 'Chinstrap'], dtype='object')

# %%
data = df['species'].value_counts(sort=False)
plt.figure(figsize=(5,3))
plt.bar(data.index, data, color = ['r', 'b', 'g'])
plt.ylabel('Amount')
plt.xlabel('Type')
plt.title('Distribution of penguin species')
plt.show()

# %% [markdown]
# # - Flipper Length vs. Body Mass: Create a scatter plot to analyze the relationship between flipper length and body mass, color-coded by species.

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(data=df, x='flipper_length_mm', y='body_mass_g', hue='species', palette='bright')

plt.title('Flipper Length vs. Body Mass')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Body Mass (g)')
plt.show()

# %% [markdown]
# # - Island Distribution: Visualize the count of penguins on each island using a pie chart.

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 4       3450.0  female  2007
# 5       3650.0    male  2007

# %%
island_counts = df['island'].value_counts()

plt.figure(figsize=(5, 5))
plt.pie(island_counts, labels=island_counts.index, autopct='%1.1f%%')
plt.title('Island Distribution')
plt.show()

# %% [markdown]
# # - Sex Distribution within Species: Create grouped bar charts showing the distribution of sex within each penguin species

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='species', hue='sex', data=df, palette='dark')

plt.title('Sex Distribution')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # - Heatmap of Correlations: Plot a heatmap to visualize the correlations between numerical variables.

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Heatmap of Correlation')

plt.show()
# Out:
# <ipython-input-46-1700e9779628>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# # - Boxplots for Measurements: Generate boxplots for flipper length, body mass, and bill measurements, segmented by species.

# %%
sns.boxplot(x='species', y='flipper_length_mm', data=df)


plt.title('Flipper Length by Species')


plt.show()

# %%
sns.boxplot(x='species', y='body_mass_g', data=df)
plt.title('Body Mass by Species')

plt.show()

# %%
sns.boxplot(x='species', y='bill_length_mm', data=df)
plt.title('Bill Length by Species')
plt.show()

# %% [markdown]
# # - Histograms of Measurements: Create histograms to show the distribution of key measurements (bill length, bill depth, flipper length).

# %%
plt.figure(figsize=(15, 3))

plt.subplot(1, 3, 1)
sns.histplot(df['bill_length_mm'], kde=True)
plt.title('Distribution - bill length')


plt.subplot(1, 3, 2)
sns.histplot(df['bill_depth_mm'], kde=True)
plt.title('Distribution - bill depth')

plt.subplot(1, 3, 3)
sns.histplot(df['flipper_length_mm'], kde=True)
plt.title('Distribution - flipper length')

plt.show()

# %% [markdown]
# # Conclusion:

# %% [markdown]
# Most kind of penguins in the dataset belong to the Adelie species, as evidenced by the bar chart showing species.
#
# The scatter plot indicates a positive correlation between flipper length and body mass among the penguins.
#
# The relationship between flipper length and body weight is clearer in Gentoo. The Gentoo species has larger flippers and body mass
#
# The pie chart reveals that most of all penguins in this dataset are located on Biscoe Island.
#
# There are representatives of both sexes in sex distribution.
#
# The heatmap displays significant correlations between some measurements, such as flipper length and body mass.
