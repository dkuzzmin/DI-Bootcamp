# %% [markdown]
# <a href="https://colab.research.google.com/github/dkuzzmin/DI-Bootcamp/blob/main/Week5/Day1/W5_Day1_XC_XP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Exercise 1 : Understanding Data Visualization**

# %% [markdown]
# **Data visualization makes it easier for non-specialists to understand complex data and helps identify key patterns**

# %% [markdown]
# **Line graphs are used to display changes and trends in data over time, allowing you to compare them**

# %% [markdown]
# 🌟  **Exercise 2 : Creating A Line Plot For Temperature Variation**

# %%
temp = [-3, -3, -6, -7, -6, -4, -5]
day = ['Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday']

plt.plot(day, temp, marker='*')
plt.xlabel('Days')
plt.ylabel('Temperature, Co')
plt.title('Temperature in Kazan (Russia)')
plt.show()

# %% [markdown]
# **Exercise 3 : Visualizing Monthly Sales With A Bar Chart**

# %%
month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sales = np.random.normal(12000, 3000, 12)
sales
# Out:
# array([ 8380.37472443, 14991.99133005,  4869.40506051,  8575.85972921,
#         7607.04300028, 15825.29191482,  6019.41619367,  9340.83456816,
#        20743.33609369, 12493.52279279, 10310.93615888, 10431.58244246])

# %%
plt.bar(month, sales, hatch='*')
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales Amount($)')
plt.show()

# %% [markdown]
# **Exercise 4 : Data Visualisation**

# %%
df = pd.read_csv('sales_data.csv')
df
# Out:
#            date     product     category   price  quantity  revenue
# 0    2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1    2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2    2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3    2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4    2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0
# ..          ...         ...          ...     ...       ...      ...
# 364  2022-12-27       Watch  Accessories   150.0       5.0    750.0
# 365  2022-12-28        Coat     Clothing   100.0       5.0    500.0
# 366  2022-12-29  Headphones  Electronics   100.0      10.0   1000.0
# 367  2022-12-30  Smartphone  Electronics   600.0      11.0   6600.0
# 368  2022-12-31      Hoodie     Clothing    40.0      30.0   1200.0
#
# [369 rows x 6 columns]

# %% [markdown]
# Calculate the total quantity of products sold by the company.

# %%
df['quantity'].sum()
# Out:
# 5360.0

# %% [markdown]
# Identify the category that had the highest revenue and calculate how much revenue it generated.

# %%
df.groupby('category')['revenue'].sum().max()
# Out:
# 516080.0

# %% [markdown]
# Determine the average revenue per sale in the dataset.

# %%
round(df['revenue'].mean())
# Out:
# 2061

# %% [markdown]
# Create a bar chart to visualize the total revenue generated in each quarter of the year (Q1, Q2, Q3, Q4).

# %%
q1 = df[('2022-01-01' <= df['date']) & (df['date'] <= '2022-03-31')]['revenue'].sum()
q2 = df[('2022-04-01' <= df['date']) & (df['date'] <= '2022-06-30')]['revenue'].sum()
q3 = df[('2022-07-01' <= df['date']) & (df['date'] <= '2022-09-30')]['revenue'].sum()
q4 = df[('2022-10-01' <= df['date']) & (df['date'] <= '2022-12-31')]['revenue'].sum()

# %%
x = ['Q1', 'Q2', 'Q3', 'Q4']
y = [q1,q2,q3,q4]

# %%
plt.bar(x,y, color = ['gray','b','c','g'], hatch = '/')
plt.title('Total revenue by quarter, 2022')
plt.show()

# %%
q1+q2+q3+q4
# Out:
# 758330.0

# %%
df['revenue'].sum()
# Out:
# 758330.0

# %% [markdown]
# **Exercise 5 : Data Visualisation Using MatPlotLib**

# %%
x = np.random.randint(-10,10,50)
x = pd.Series(x)
x = x.sort_values().values
y = x * x

# %%
plt.plot(x,y)
plt.title('y = x ^ 2')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
products = ['A','B','C','D']
sales = [15, 30, 45, 20]

plt.bar(products, sales, color='red')
plt.xlabel('Products')
plt.ylabel('Sales')
plt.title('Week Sales')
plt.show()

# %%
x = ['Apples', 'Bananas', 'Cherries', 'Dates']
y = [40, 30, 20, 10]

plt.figure(figsize=(10, 5))

plt.pie(y, labels = x, colors=['green', 'yellow', 'blue', 'red'])
plt.title('Favorite Fruits')
plt.legend(x)
plt.axis('equal')

plt.show()
